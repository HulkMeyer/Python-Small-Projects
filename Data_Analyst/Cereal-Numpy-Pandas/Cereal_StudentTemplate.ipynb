# %% [markdown]
# # Cereal Dataset
# ## Numpy and Pandas Notebook
#
# In this exercise you will use a dataset containing information about different cereals in order to further your knowledge of NumPy and Pandas.  Before expanding our knowledge we will first review some data exploration basics.
#
# First, download the notebook and the .csv file `cereal.csv` and place them in the same folder.
#
# In this notebook, you will be asked to first practice some basic NumPy and Pandas skills. Practice is extremely important in building your manipulation skills so you should attempt to complete the task yourself before watching the solution.
#
# Also note that there are sometimes different ways to do the same thing when using Python, NumPy, and Pandas for data manipulation. Some ways are more efficient than others, especially with larger data sets, but since these datasets are so small, the suggested solutions may not be the most efficient. Instead, our goal is to show you different options when it comes to completing the tasks.
#
# The complete dataset can be found here: [Kaggle](https://www.kaggle.com/crawford/80-cereals)
#
# |Variable | Description|
# |:--------|:-----------|
# |Name| Name of cereal
# |mfr| Manufacturer of cereal|
# |type| hot or cold|
# |calories| calories per serving|
# |protein| grams of protein|
# |fat| grams of fat|
# |sodium| milligrams of sodium|
# |fiber| grams of dietary fiber|
# |carbo| grams of complex carbohydrates|
# |sugars| grams of sugars|
# |potass| milligrams of potassium|
# |vitamins| vitamins and minerals - 0, 25, or 100, indicating the typical percentage of FDA recommended|
# |shelf| display shelf (1, 2, or 3, counting from the floor)|
# |weight| weight in ounces of one serving|
# |cups| number of cups in one serving|
# |rating| a rating of the cereals (Possibly from Consumer Reports?)|

# %% [markdown]
# # Exploration

# %% [markdown]
# ### Initial Imports

# %%
# import common libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load data from csv

data = pd.read_csv('cereal.csv', index_col = 'name') #ensure file is in same location as notebook or add path

# %% [markdown]
# First look at `cereal`

# %%
# head

data.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %%
# shape

data.shape
# Out:
# (77, 15)

# %% [markdown]
# 77 observations, 15 variables
#
# Now lets see what the columns are named:

# %%
# columns

for i in data.columns:
    print(i)
# Out:
# mfr
# type
# calories
# protein
# fat
# sodium
# fiber
# carbo
# sugars
# potass
# vitamins
# shelf
# weight
# cups
# rating

# %% [markdown]
# There are several ways to get a quick view of your data:
#
# * the `head()` method (seen above) provides a quick look at the first several rows of your data
# * the `info()` method provides a brief summary of your DataFrame including non-null count and data types
# * the `describe()` method provides descriptive statistics of numerical data

# %%
# info

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     77 non-null     float64
#  8   sugars    77 non-null     int64
#  9   potass    77 non-null     int64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 9.6+ KB

# %%
# describe

data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
# number of observations

len(data)
# Out:
# 77

# %%
# descriptives for calories

data.calories.describe()
# Out:
# count     77.000000
# mean     106.883117
# std       19.484119
# min       50.000000
# 25%      100.000000
# 50%      110.000000
# 75%      110.000000
# max      160.000000
# Name: calories, dtype: float64

# %% [markdown]
# We can view unique values using `unique()` and identify the counts using `value_counts()`
#
# Let's look at manufacturer

# %%
# unique manufacturers

data.mfr.unique()
# Out:
# array(['N', 'Q', 'K', 'R', 'G', 'P', 'A'], dtype=object)

# %%
# manufacturer value counts

data.mfr.value_counts()
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
# pivot table for calories by manufacturer

data.pivot_table('calories', 'mfr')
# Out:
#        calories
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     86.666667
# P    108.888889
# Q     95.000000
# R    115.000000

# %%
# pivot table for calories by manufacturer by type

data.pivot_table('calories', 'mfr', 'type')
# Out:
# type           C      H
# mfr
# A            NaN  100.0
# G     111.363636    NaN
# K     108.695652    NaN
# N      84.000000  100.0
# P     108.888889    NaN
# Q      94.285714  100.0
# R     115.000000    NaN

# %% [markdown]
# # Selecting columns

# %% [markdown]
# We're interested in calories, manufacturer, cups, rating, and cost (which doesn't yet exist)

# %%
# select variables of interest - including cost

data2 = pd.DataFrame(data, columns = ['calories', 'mfr', 'cups', 'rating', 'cost'])
data2
# Out:
#                            calories mfr  cups     rating  cost
# name
# 100% Bran                        70   N  0.33  68.402973   NaN
# 100% Natural Bran               120   Q  1.00  33.983679   NaN
# All-Bran                         70   K  0.33  59.425505   NaN
# All-Bran with Extra Fiber        50   K  0.50  93.704912   NaN
# Almond Delight                  110   R  0.75  34.384843   NaN
# ...                             ...  ..   ...        ...   ...
# Triples                         110   G  0.75  39.106174   NaN
# Trix                            110   G  1.00  27.753301   NaN
# Wheat Chex                      100   R  0.67  49.787445   NaN
# Wheaties                        100   G  1.00  51.592193   NaN
# Wheaties Honey Gold             110   G  0.75  36.187559   NaN
#
# [77 rows x 5 columns]

# %% [markdown]
# Notice `cost` = NaN because it didn't exist before selecting it

# %%
# this doesn't work (not including cost)

data['calories', 'mfr', 'cups', 'rating']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('calories', 'mfr', 'cups', 'rating')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 3>()
#       1 # this doesn't work (not including cost)
# ----> 3 data['calories', 'mfr', 'cups', 'rating']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ('calories', 'mfr', 'cups', 'rating')

# %%
# select multiple variables - but not cost

data[['calories', 'mfr', 'cups', 'rating']]
# Out:
#                            calories mfr  cups     rating
# name
# 100% Bran                        70   N  0.33  68.402973
# 100% Natural Bran               120   Q  1.00  33.983679
# All-Bran                         70   K  0.33  59.425505
# All-Bran with Extra Fiber        50   K  0.50  93.704912
# Almond Delight                  110   R  0.75  34.384843
# ...                             ...  ..   ...        ...
# Triples                         110   G  0.75  39.106174
# Trix                            110   G  1.00  27.753301
# Wheat Chex                      100   R  0.67  49.787445
# Wheaties                        100   G  1.00  51.592193
# Wheaties Honey Gold             110   G  0.75  36.187559
#
# [77 rows x 4 columns]

# %%
# this doesn't work, either

data[['calories', 'mfr', 'cups', 'rating', 'cost']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#       1 # this doesn't work, either
# ----> 3 data[['calories', 'mfr', 'cups', 'rating', 'cost']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['cost'] not in index"

# %%
# set cost to $3.50

data2['cost'] = 3.5
data2
# Out:
#                            calories mfr  cups     rating  cost
# name
# 100% Bran                        70   N  0.33  68.402973   3.5
# 100% Natural Bran               120   Q  1.00  33.983679   3.5
# All-Bran                         70   K  0.33  59.425505   3.5
# All-Bran with Extra Fiber        50   K  0.50  93.704912   3.5
# Almond Delight                  110   R  0.75  34.384843   3.5
# ...                             ...  ..   ...        ...   ...
# Triples                         110   G  0.75  39.106174   3.5
# Trix                            110   G  1.00  27.753301   3.5
# Wheat Chex                      100   R  0.67  49.787445   3.5
# Wheaties                        100   G  1.00  51.592193   3.5
# Wheaties Honey Gold             110   G  0.75  36.187559   3.5
#
# [77 rows x 5 columns]

# %%
# create random values for cost

np.random.seed(56)

costs = np.random.uniform(low = 2.5, high = 4.5, size = (len(data2))).round(2)

data2['cost'] = costs
data2
# Out:
#                            calories mfr  cups     rating  cost
# name
# 100% Bran                        70   N  0.33  68.402973  4.47
# 100% Natural Bran               120   Q  1.00  33.983679  3.17
# All-Bran                         70   K  0.33  59.425505  3.85
# All-Bran with Extra Fiber        50   K  0.50  93.704912  2.89
# Almond Delight                  110   R  0.75  34.384843  3.21
# ...                             ...  ..   ...        ...   ...
# Triples                         110   G  0.75  39.106174  3.37
# Trix                            110   G  1.00  27.753301  3.31
# Wheat Chex                      100   R  0.67  49.787445  3.17
# Wheaties                        100   G  1.00  51.592193  2.57
# Wheaties Honey Gold             110   G  0.75  36.187559  2.94
#
# [77 rows x 5 columns]

# %%
# when assigning values, they must be the correct size
# notice here we have 78 values, not 77, which will cause an error

np.random.seed(56)

costs2 = np.random.uniform(low = 2.5, high = 4.5, size = (78)).round(2)
data2['cost'] = costs2

data2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 7>()
#       4 np.random.seed(56)
#       6 costs2 = np.random.uniform(low = 2.5, high = 4.5, size = (78)).round(2)
# ----> 7 data2['cost'] = costs2
#       9 data2
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (78) does not match length of index (77)

# %% [markdown]
# Now we want identify only those with values greater than 3.50m

# %%
# create new boolean where costs > 3.5

data2['cost2'] = data2['cost'] > 3.5

data2
# Out:
#                            calories mfr  cups     rating  cost  cost2
# name
# 100% Bran                        70   N  0.33  68.402973  4.47   True
# 100% Natural Bran               120   Q  1.00  33.983679  3.17  False
# All-Bran                         70   K  0.33  59.425505  3.85   True
# All-Bran with Extra Fiber        50   K  0.50  93.704912  2.89  False
# Almond Delight                  110   R  0.75  34.384843  3.21  False
# ...                             ...  ..   ...        ...   ...    ...
# Triples                         110   G  0.75  39.106174  3.37  False
# Trix                            110   G  1.00  27.753301  3.31  False
# Wheat Chex                      100   R  0.67  49.787445  3.17  False
# Wheaties                        100   G  1.00  51.592193  2.57  False
# Wheaties Honey Gold             110   G  0.75  36.187559  2.94  False
#
# [77 rows x 6 columns]

# %%
# let's use `del` to delete `cost2` - we don't need it

del data2['cost2']
data2
# Out:
#                            calories mfr  cups     rating  cost
# name
# 100% Bran                        70   N  0.33  68.402973  4.47
# 100% Natural Bran               120   Q  1.00  33.983679  3.17
# All-Bran                         70   K  0.33  59.425505  3.85
# All-Bran with Extra Fiber        50   K  0.50  93.704912  2.89
# Almond Delight                  110   R  0.75  34.384843  3.21
# ...                             ...  ..   ...        ...   ...
# Triples                         110   G  0.75  39.106174  3.37
# Trix                            110   G  1.00  27.753301  3.31
# Wheat Chex                      100   R  0.67  49.787445  3.17
# Wheaties                        100   G  1.00  51.592193  2.57
# Wheaties Honey Gold             110   G  0.75  36.187559  2.94
#
# [77 rows x 5 columns]

# %%
# we can index our original dataset using this value, as well

data3 = data2[data2['cost']>3.5]

data3.head()
# Out:
#                          calories mfr  cups     rating  cost
# name
# 100% Bran                      70   N  0.33  68.402973  4.47
# All-Bran                       70   K  0.33  59.425505  3.85
# Apple Cinnamon Cheerios       110   G  0.75  29.509541  4.13
# Bran Chex                      90   R  0.67  49.120253  4.25
# Cinnamon Toast Crunch         120   G  0.75  19.823573  4.17

# %%
print(data2['cost']>3.5)
# Out:
# name
# 100% Bran                     True
# 100% Natural Bran            False
# All-Bran                      True
# All-Bran with Extra Fiber    False
# Almond Delight               False
#                              ...
# Triples                      False
# Trix                         False
# Wheat Chex                   False
# Wheaties                     False
# Wheaties Honey Gold          False
# Name: cost, Length: 77, dtype: bool

# %% [markdown]
# ### Selecting rows
#
# As with selecting columns, there are frequently multiple ways to accomplish tasks
#
# To select observations we can use `.loc` and `.iloc`
#
# `.loc` = axis labels
#
# `.iloc` = integers

# %%
data.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %%
data.loc['All-Bran']
# Out:
# mfr                 K
# type                C
# calories           70
# protein             4
# fat                 1
# sodium            260
# fiber             9.0
# carbo             7.0
# sugars              5
# potass            320
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.33
# rating      59.425505
# Name: All-Bran, dtype: object

# %%
data.iloc[2]
# Out:
# mfr                 K
# type                C
# calories           70
# protein             4
# fat                 1
# sodium            260
# fiber             9.0
# carbo             7.0
# sugars              5
# potass            320
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.33
# rating      59.425505
# Name: All-Bran, dtype: object

# %% [markdown]
# We can select values by indicating the row(s) and column(s) we're interested in

# %%
data.loc['All-Bran', 'fiber']
# Out:
# 9.0

# %%
# use brackets instead of parentheses as shown in module video to prevent later problems
data.loc[['All-Bran', 'Almond Delight'], 'fiber']
# Out:
# name
# All-Bran          9.0
# Almond Delight    1.0
# Name: fiber, dtype: float64

# %%
# use brackets instead of parentheses as shown in module video to prevent later problems
data.loc[['All-Bran', 'Almond Delight'], ['fiber', 'mfr']]
# Out:
#                 fiber mfr
# name
# All-Bran          9.0   K
# Almond Delight    1.0   R

# %% [markdown]
# # Reinforcement
#
# #### Student Practice
# Pause the video and try to perform the following tasks on the `cereal` dataset. Then check your answers as I walk through the solutions.

# %% [markdown]
# **Exercise:** Select only the `protein` column from the data.

# %%
# select only variable protein

data['protein']
# Out:
# name
# 100% Bran                    4
# 100% Natural Bran            3
# All-Bran                     4
# All-Bran with Extra Fiber    4
# Almond Delight               2
#                             ..
# Triples                      2
# Trix                         1
# Wheat Chex                   3
# Wheaties                     3
# Wheaties Honey Gold          2
# Name: protein, Length: 77, dtype: int64

# %% [markdown]
# **Exercise:** Select the `fat`, `calories`, and `sugars` columns from the data.

# %%
# select only variables fat, calories, sugars

data[['fat', 'calories','sugars']]
# Out:
#                            fat  calories  sugars
# name
# 100% Bran                    1        70       6
# 100% Natural Bran            5       120       8
# All-Bran                     1        70       5
# All-Bran with Extra Fiber    0        50       0
# Almond Delight               2       110       8
# ...                        ...       ...     ...
# Triples                      1       110       3
# Trix                         1       110      12
# Wheat Chex                   1       100       3
# Wheaties                     1       100       3
# Wheaties Honey Gold          1       110       8
#
# [77 rows x 3 columns]

# %% [markdown]
# **Exercise:** Select the following observations from the data: `Cocoa Puffs`, `Frosted Flakes`, and `Fruity Pebbles`.

# %%
# select observations Cocoa Puffs, Frosted Flakes, and Fruity Pebbles

data.loc[['Cocoa Puffs','Frosted Flakes','Fruity Pebbles']]
# Out:
#                mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Cocoa Puffs      G    C       110        1    1     180    0.0   12.0      13
# Frosted Flakes   K    C       110        1    0     200    1.0   14.0      11
# Fruity Pebbles   P    C       110        1    1     135    0.0   13.0      12
#
#                 potass  vitamins  shelf  weight  cups     rating
# name
# Cocoa Puffs         55        25      2     1.0  1.00  22.736446
# Frosted Flakes      25        25      1     1.0  0.75  31.435973
# Fruity Pebbles      25        25      2     1.0  0.75  28.025765

# %% [markdown]
# **Exercise:** Select the cereals that have `fiber` greater than 10.

# %%
# select variable fiber where values are greater than 10

data.loc[data['fiber'] > 10]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
#
#                            cups     rating
# name
# All-Bran with Extra Fiber   0.5  93.704912

# %% [markdown]
# **Exercise:** Import the csv file called `myratings.csv` and save it as a DataFrame called `myratings`.

# %%
# import myratings.csv

myratings = pd.read_csv('myratings.csv')

# %% [markdown]
# **Exercise:** Output the `myratings` DataFrame.  How many rows of data do we have?  Can you figure out why we do not have 77 rows as we did in the original `cereal` data?

# %%
# what do we have?

myratings
# Out:
#     myrating
# 0          1
# 1          2
# 2          3
# 3          3
# 4          3
# 5          3
# 6          5
# 7          3
# 8          3
# 9          2
# 10         4
# 11         5
# 12         4
# 13         3
# 14         2
# 15         3
# 16         5
# 17         5
# 18         1
# 19         4
# 20         3
# 21         4
# 22         3
# 23         3
# 24         5
# 25         2
# 26         2
# 27         4
# 28         5
# 29         1
# 30         3
# 31         2

# %% [markdown]
# **Exercise:** Check [Pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) to determine what is the default for handling blank lines of data.  How could you change this to interpret blank lines as NaN values instead of skipping them?
#
# Import the `myratings.csv` file again, saving it was `myratings`, but this time making sure that blank lines are treated as missing values.

# %%
# import myratings.csv

myratings = pd.read_csv('myratings.csv', skip_blank_lines = False)   
#Pandas will automatically exclude blank likes this keeps them in so they will show up NAN
myratings
# Out:
#     myrating
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        2.0
# ..       ...
# 72       NaN
# 73       1.0
# 74       NaN
# 75       3.0
# 76       2.0
#
# [77 rows x 1 columns]

# %% [markdown]
# **Exercise:** Set the index of `myratings` as the same as the index of the `cereal` data (created as `data` above).

# %%
# set index to cereal name

myratings.set_index(data.index, inplace = True)
myratings
# Out:
#                            myrating
# name
# 100% Bran                       1.0
# 100% Natural Bran               NaN
# All-Bran                        NaN
# All-Bran with Extra Fiber       NaN
# Almond Delight                  2.0
# ...                             ...
# Triples                         NaN
# Trix                            1.0
# Wheat Chex                      NaN
# Wheaties                        3.0
# Wheaties Honey Gold             2.0
#
# [77 rows x 1 columns]

# %% [markdown]
# **Exercise:** How many missing values are represented in the `myratings` data?

# %%
# count missing values

myratings.isnull().sum()
# Out:
# myrating    45
# dtype: int64

# %% [markdown]
# **Exercise:** Merge the `data` DataFrame and the `myratings` DataFrame.

# %%
# merge myratings with original dataframe

data = pd.merge(data, myratings, on = 'name')
data
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Triples                     21.0       3      60        25      3     1.0
# Trix                        13.0      12      25        25      2     1.0
# Wheat Chex                  17.0       3     115        25      1     1.0
# Wheaties                    17.0       3     110        25      1     1.0
# Wheaties Honey Gold         16.0       8      60        25      1     1.0
#
#                            cups     rating  myrating
# name
# 100% Bran                  0.33  68.402973       1.0
# 100% Natural Bran          1.00  33.983679       NaN
# All-Bran                   0.33  59.425505       NaN
# All-Bran with Extra Fiber  0.50  93.704912       NaN
# Almond Delight             0.75  34.384843       2.0
# ...                         ...        ...       ...
# Triples                    0.75  39.106174       NaN
# Trix                       1.00  27.753301       1.0
# Wheat Chex                 0.67  49.787445       NaN
# Wheaties                   1.00  51.592193       3.0
# Wheaties Honey Gold        0.75  36.187559       2.0
#
# [77 rows x 16 columns]

# %% [markdown]
# **Exercise:** The `myrating` attribute is on a scale of 1-5 while the rating attribute from the original data is on a scale of 0-100.
#
# Create a new column called `myrating20` that multiplies the `myrating` column by 20 so that is has the same scale as the original data.

# %%
# multiply myrating variable by 20

data['my rating20'] = data['myrating']*20
data
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Triples                     21.0       3      60        25      3     1.0
# Trix                        13.0      12      25        25      2     1.0
# Wheat Chex                  17.0       3     115        25      1     1.0
# Wheaties                    17.0       3     110        25      1     1.0
# Wheaties Honey Gold         16.0       8      60        25      1     1.0
#
#                            cups     rating  myrating  my rating20
# name
# 100% Bran                  0.33  68.402973       1.0         20.0
# 100% Natural Bran          1.00  33.983679       NaN          NaN
# All-Bran                   0.33  59.425505       NaN          NaN
# All-Bran with Extra Fiber  0.50  93.704912       NaN          NaN
# Almond Delight             0.75  34.384843       2.0         40.0
# ...                         ...        ...       ...          ...
# Triples                    0.75  39.106174       NaN          NaN
# Trix                       1.00  27.753301       1.0         20.0
# Wheat Chex                 0.67  49.787445       NaN          NaN
# Wheaties                   1.00  51.592193       3.0         60.0
# Wheaties Honey Gold        0.75  36.187559       2.0         40.0
#
# [77 rows x 17 columns]

# %% [markdown]
# **Exercise:** What is the difference between the original `rating` column and the `myrating20` column?  Create a new column called `diff` that subtracts the `myrating20` column from the `rating` column.

# %%
# calculate difference 

data['diff'] = data['rating'] - data['my rating20']
data
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Triples                     21.0       3      60        25      3     1.0
# Trix                        13.0      12      25        25      2     1.0
# Wheat Chex                  17.0       3     115        25      1     1.0
# Wheaties                    17.0       3     110        25      1     1.0
# Wheaties Honey Gold         16.0       8      60        25      1     1.0
#
#                            cups     rating  myrating  my rating20       diff
# name
# 100% Bran                  0.33  68.402973       1.0         20.0  48.402973
# 100% Natural Bran          1.00  33.983679       NaN          NaN        NaN
# All-Bran                   0.33  59.425505       NaN          NaN        NaN
# All-Bran with Extra Fiber  0.50  93.704912       NaN          NaN        NaN
# Almond Delight             0.75  34.384843       2.0         40.0  -5.615157
# ...                         ...        ...       ...          ...        ...
# Triples                    0.75  39.106174       NaN          NaN        NaN
# Trix                       1.00  27.753301       1.0         20.0   7.753301
# Wheat Chex                 0.67  49.787445       NaN          NaN        NaN
# Wheaties                   1.00  51.592193       3.0         60.0  -8.407807
# Wheaties Honey Gold        0.75  36.187559       2.0         40.0  -3.812441
#
# [77 rows x 18 columns]

# %% [markdown]
# **Exercise:** Find the cereals with the five largest differences values.

# %%
# find five largest differences

data.nlargest(5, ['diff'])

#could sort by diff column in descending order and then do head(5)
# Out:
#                mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# 100% Bran        N    C        70        4    1     130   10.0    5.0       6
# Shredded Wheat   N    C        80        2    0       0    3.0   16.0       0
# Kix              G    C       110        2    1     260    0.0   21.0       3
# Trix             G    C       110        1    1     140    0.0   13.0      12
# Corn Flakes      K    C       100        2    0     290    1.0   21.0       2
#
#                 potass  vitamins  shelf  weight  cups     rating  myrating  \
# name
# 100% Bran          280        25      3    1.00  0.33  68.402973       1.0
# Shredded Wheat      95         0      1    0.83  1.00  68.235885       2.0
# Kix                 40        25      2    1.00  1.50  39.241114       1.0
# Trix                25        25      2    1.00  1.00  27.753301       1.0
# Corn Flakes         35        25      1    1.00  1.00  45.863324       2.0
#
#                 my rating20       diff
# name
# 100% Bran              20.0  48.402973
# Shredded Wheat         40.0  28.235885
# Kix                    20.0  19.241114
# Trix                   20.0   7.753301
# Corn Flakes            40.0   5.863324

# %% [markdown]
# ## Create per cup amounts
#
# #### Student Practice
# Pause the video and try to perform the following tasks on the `cereal` dataset. Then check your answers as I walk through the solutions.

# %% [markdown]
# **Exercise:** Create four new variables called:
#
# * `calPerCup` - calories per cup
# * `proPerCup` - protein per cup
# * `fatPerCup` - fat per cup
# * `sugPerCup` - sugar per cup
#
# All created by taking the variable and dividing by cups (e.g., calories/cups)

# %%
# create 'calPerCup', 'proPerCup', 'fatPerCup', 'sugPerCup' variables as ratio of variable to cups

data['calPerCup'] = data['calories'] / data['cups']
data['proPerCup'] = data['protein'] / data['cups']
data['fatPerCup'] = data['fat'] / data['cups']
data['sugPerCup'] = data['sugars'] / data['cups']
data
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  ...  weight  cups  \
# name                                              ...
# 100% Bran                    5.0       6     280  ...     1.0  0.33
# 100% Natural Bran            8.0       8     135  ...     1.0  1.00
# All-Bran                     7.0       5     320  ...     1.0  0.33
# All-Bran with Extra Fiber    8.0       0     330  ...     1.0  0.50
# Almond Delight              14.0       8      -1  ...     1.0  0.75
# ...                          ...     ...     ...  ...     ...   ...
# Triples                     21.0       3      60  ...     1.0  0.75
# Trix                        13.0      12      25  ...     1.0  1.00
# Wheat Chex                  17.0       3     115  ...     1.0  0.67
# Wheaties                    17.0       3     110  ...     1.0  1.00
# Wheaties Honey Gold         16.0       8      60  ...     1.0  0.75
#
#                               rating  myrating  my rating20       diff  \
# name
# 100% Bran                  68.402973       1.0         20.0  48.402973
# 100% Natural Bran          33.983679       NaN          NaN        NaN
# All-Bran                   59.425505       NaN          NaN        NaN
# All-Bran with Extra Fiber  93.704912       NaN          NaN        NaN
# Almond Delight             34.384843       2.0         40.0  -5.615157
# ...                              ...       ...          ...        ...
# Triples                    39.106174       NaN          NaN        NaN
# Trix                       27.753301       1.0         20.0   7.753301
# Wheat Chex                 49.787445       NaN          NaN        NaN
# Wheaties                   51.592193       3.0         60.0  -8.407807
# Wheaties Honey Gold        36.187559       2.0         40.0  -3.812441
#
#                             calPerCup  proPerCup  fatPerCup  sugPerCup
# name
# 100% Bran                  212.121212  12.121212   3.030303  18.181818
# 100% Natural Bran          120.000000   3.000000   5.000000   8.000000
# All-Bran                   212.121212  12.121212   3.030303  15.151515
# All-Bran with Extra Fiber  100.000000   8.000000   0.000000   0.000000
# Almond Delight             146.666667   2.666667   2.666667  10.666667
# ...                               ...        ...        ...        ...
# Triples                    146.666667   2.666667   1.333333   4.000000
# Trix                       110.000000   1.000000   1.000000  12.000000
# Wheat Chex                 149.253731   4.477612   1.492537   4.477612
# Wheaties                   100.000000   3.000000   1.000000   3.000000
# Wheaties Honey Gold        146.666667   2.666667   1.333333  10.666667
#
# [77 rows x 22 columns]

# %% [markdown]
# **Exercise:** Create a scatterplot of `calories` by `calPerCup`.  You can use Matplotlib or Seaborn.

# %%
# create scatterplot for calories by calPerCup
# I changed this up and wanted to look at all for of them compared to calories
plt.style.use('ggplot')

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, sharex = True, figsize = (15,15))

scatter_calPerCup = ax1.scatter(x = data['calories'], y = data['calPerCup'], cmap = 'Paired')
scatter_proPerCup = ax2.scatter(x = data['calories'], y = data['proPerCup'], cmap = 'Paired')
scatter_fatPerCup = ax3.scatter(x = data['calories'], y = data['fatPerCup'], cmap = 'Paired')
scatter_sugPerCup = ax4.scatter(x = data['calories'], y = data['sugPerCup'], cmap = 'Paired')

plt.suptitle('Per Cup Data', fontsize = 40)

ax1.set(xlabel = 'Calories', ylabel = 'Calories Per Cup', title = 'Cals Per Cup VS. Calories')
ax2.set(xlabel = 'Calories', ylabel = 'Protein Per Cup', title = 'Protein Per Cup VS. Calories')
ax3.set(xlabel = 'Calories', ylabel = 'Fat Per Cup', title = 'Fat Per Cup VS. Calories')
ax4.set(xlabel = 'Calories', ylabel = 'Sugar Per Cup', title = 'Sugar Per Cup VS. Calories')

plt.show()

# %% [markdown]
# **Exercise:** Which cereal has the highest calories per cup?

# %%
# which cereal had the highest calories per cup?

mostCalCup = data.nlargest(1, ['calPerCup'])
mostCalCup
# Out:
#            mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Grape-Nuts   P    C       110        3    0     170    3.0   17.0       3
#
#             potass  ...  weight  cups     rating  myrating  my rating20  diff  \
# name                ...
# Grape-Nuts      90  ...     1.0  0.25  53.371007       NaN          NaN   NaN
#
#             calPerCup  proPerCup  fatPerCup  sugPerCup
# name
# Grape-Nuts      440.0       12.0        0.0       12.0
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Sorting

# %% [markdown]
# **Exercise:** Sort `data` by index.

# %%
# sort index alphabetically

data.sort_index()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  ...  weight  cups  \
# name                                              ...
# 100% Bran                    5.0       6     280  ...     1.0  0.33
# 100% Natural Bran            8.0       8     135  ...     1.0  1.00
# All-Bran                     7.0       5     320  ...     1.0  0.33
# All-Bran with Extra Fiber    8.0       0     330  ...     1.0  0.50
# Almond Delight              14.0       8      -1  ...     1.0  0.75
# ...                          ...     ...     ...  ...     ...   ...
# Triples                     21.0       3      60  ...     1.0  0.75
# Trix                        13.0      12      25  ...     1.0  1.00
# Wheat Chex                  17.0       3     115  ...     1.0  0.67
# Wheaties                    17.0       3     110  ...     1.0  1.00
# Wheaties Honey Gold         16.0       8      60  ...     1.0  0.75
#
#                               rating  myrating  my rating20       diff  \
# name
# 100% Bran                  68.402973       1.0         20.0  48.402973
# 100% Natural Bran          33.983679       NaN          NaN        NaN
# All-Bran                   59.425505       NaN          NaN        NaN
# All-Bran with Extra Fiber  93.704912       NaN          NaN        NaN
# Almond Delight             34.384843       2.0         40.0  -5.615157
# ...                              ...       ...          ...        ...
# Triples                    39.106174       NaN          NaN        NaN
# Trix                       27.753301       1.0         20.0   7.753301
# Wheat Chex                 49.787445       NaN          NaN        NaN
# Wheaties                   51.592193       3.0         60.0  -8.407807
# Wheaties Honey Gold        36.187559       2.0         40.0  -3.812441
#
#                             calPerCup  proPerCup  fatPerCup  sugPerCup
# name
# 100% Bran                  212.121212  12.121212   3.030303  18.181818
# 100% Natural Bran          120.000000   3.000000   5.000000   8.000000
# All-Bran                   212.121212  12.121212   3.030303  15.151515
# All-Bran with Extra Fiber  100.000000   8.000000   0.000000   0.000000
# Almond Delight             146.666667   2.666667   2.666667  10.666667
# ...                               ...        ...        ...        ...
# Triples                    146.666667   2.666667   1.333333   4.000000
# Trix                       110.000000   1.000000   1.000000  12.000000
# Wheat Chex                 149.253731   4.477612   1.492537   4.477612
# Wheaties                   100.000000   3.000000   1.000000   3.000000
# Wheaties Honey Gold        146.666667   2.666667   1.333333  10.666667
#
# [77 rows x 22 columns]

# %% [markdown]
# **Exercise:** Sort the columns alphabetically.

# %%
# sort columns

data.sort_index(axis = 1)
# Out:
#                             calPerCup  calories  carbo  cups       diff  fat  \
# name
# 100% Bran                  212.121212        70    5.0  0.33  48.402973    1
# 100% Natural Bran          120.000000       120    8.0  1.00        NaN    5
# All-Bran                   212.121212        70    7.0  0.33        NaN    1
# All-Bran with Extra Fiber  100.000000        50    8.0  0.50        NaN    0
# Almond Delight             146.666667       110   14.0  0.75  -5.615157    2
# ...                               ...       ...    ...   ...        ...  ...
# Triples                    146.666667       110   21.0  0.75        NaN    1
# Trix                       110.000000       110   13.0  1.00   7.753301    1
# Wheat Chex                 149.253731       100   17.0  0.67        NaN    1
# Wheaties                   100.000000       100   17.0  1.00  -8.407807    1
# Wheaties Honey Gold        146.666667       110   16.0  0.75  -3.812441    1
#
#                            fatPerCup  fiber mfr  my rating20  ...  proPerCup  \
# name                                                          ...
# 100% Bran                   3.030303   10.0   N         20.0  ...  12.121212
# 100% Natural Bran           5.000000    2.0   Q          NaN  ...   3.000000
# All-Bran                    3.030303    9.0   K          NaN  ...  12.121212
# All-Bran with Extra Fiber   0.000000   14.0   K          NaN  ...   8.000000
# Almond Delight              2.666667    1.0   R         40.0  ...   2.666667
# ...                              ...    ...  ..          ...  ...        ...
# Triples                     1.333333    0.0   G          NaN  ...   2.666667
# Trix                        1.000000    0.0   G         20.0  ...   1.000000
# Wheat Chex                  1.492537    3.0   R          NaN  ...   4.477612
# Wheaties                    1.000000    3.0   G         60.0  ...   3.000000
# Wheaties Honey Gold         1.333333    1.0   G         40.0  ...   2.666667
#
#                            protein     rating  shelf  sodium  sugPerCup  \
# name
# 100% Bran                        4  68.402973      3     130  18.181818
# 100% Natural Bran                3  33.983679      3      15   8.000000
# All-Bran                         4  59.425505      3     260  15.151515
# All-Bran with Extra Fiber        4  93.704912      3     140   0.000000
# Almond Delight                   2  34.384843      3     200  10.666667
# ...                            ...        ...    ...     ...        ...
# Triples                          2  39.106174      3     250   4.000000
# Trix                             1  27.753301      2     140  12.000000
# Wheat Chex                       3  49.787445      1     230   4.477612
# Wheaties                         3  51.592193      1     200   3.000000
# Wheaties Honey Gold              2  36.187559      1     200  10.666667
#
#                            sugars  type  vitamins weight
# name
# 100% Bran                       6     C        25    1.0
# 100% Natural Bran               8     C         0    1.0
# All-Bran                        5     C        25    1.0
# All-Bran with Extra Fiber       0     C        25    1.0
# Almond Delight                  8     C        25    1.0
# ...                           ...   ...       ...    ...
# Triples                         3     C        25    1.0
# Trix                           12     C        25    1.0
# Wheat Chex                      3     C        25    1.0
# Wheaties                        3     C        25    1.0
# Wheaties Honey Gold             8     C        25    1.0
#
# [77 rows x 22 columns]

# %% [markdown]
# **Exercise:** Sort the columns in descending order alphabetically.

# %%
# sort in descending order

data.sort_index(axis = 1, ascending = False)
# Out:
#                            weight  vitamins type  sugars  sugPerCup  sodium  \
# name
# 100% Bran                     1.0        25    C       6  18.181818     130
# 100% Natural Bran             1.0         0    C       8   8.000000      15
# All-Bran                      1.0        25    C       5  15.151515     260
# All-Bran with Extra Fiber     1.0        25    C       0   0.000000     140
# Almond Delight                1.0        25    C       8  10.666667     200
# ...                           ...       ...  ...     ...        ...     ...
# Triples                       1.0        25    C       3   4.000000     250
# Trix                          1.0        25    C      12  12.000000     140
# Wheat Chex                    1.0        25    C       3   4.477612     230
# Wheaties                      1.0        25    C       3   3.000000     200
# Wheaties Honey Gold           1.0        25    C       8  10.666667     200
#
#                            shelf     rating  protein  proPerCup  ...  \
# name                                                             ...
# 100% Bran                      3  68.402973        4  12.121212  ...
# 100% Natural Bran              3  33.983679        3   3.000000  ...
# All-Bran                       3  59.425505        4  12.121212  ...
# All-Bran with Extra Fiber      3  93.704912        4   8.000000  ...
# Almond Delight                 3  34.384843        2   2.666667  ...
# ...                          ...        ...      ...        ...  ...
# Triples                        3  39.106174        2   2.666667  ...
# Trix                           2  27.753301        1   1.000000  ...
# Wheat Chex                     1  49.787445        3   4.477612  ...
# Wheaties                       1  51.592193        3   3.000000  ...
# Wheaties Honey Gold            1  36.187559        2   2.666667  ...
#
#                            my rating20  mfr  fiber fatPerCup  fat       diff  \
# name
# 100% Bran                         20.0    N   10.0  3.030303    1  48.402973
# 100% Natural Bran                  NaN    Q    2.0  5.000000    5        NaN
# All-Bran                           NaN    K    9.0  3.030303    1        NaN
# All-Bran with Extra Fiber          NaN    K   14.0  0.000000    0        NaN
# Almond Delight                    40.0    R    1.0  2.666667    2  -5.615157
# ...                                ...  ...    ...       ...  ...        ...
# Triples                            NaN    G    0.0  1.333333    1        NaN
# Trix                              20.0    G    0.0  1.000000    1   7.753301
# Wheat Chex                         NaN    R    3.0  1.492537    1        NaN
# Wheaties                          60.0    G    3.0  1.000000    1  -8.407807
# Wheaties Honey Gold               40.0    G    1.0  1.333333    1  -3.812441
#
#                            cups  carbo  calories   calPerCup
# name
# 100% Bran                  0.33    5.0        70  212.121212
# 100% Natural Bran          1.00    8.0       120  120.000000
# All-Bran                   0.33    7.0        70  212.121212
# All-Bran with Extra Fiber  0.50    8.0        50  100.000000
# Almond Delight             0.75   14.0       110  146.666667
# ...                         ...    ...       ...         ...
# Triples                    0.75   21.0       110  146.666667
# Trix                       1.00   13.0       110  110.000000
# Wheat Chex                 0.67   17.0       100  149.253731
# Wheaties                   1.00   17.0       100  100.000000
# Wheaties Honey Gold        0.75   16.0       110  146.666667
#
# [77 rows x 22 columns]

# %% [markdown]
# **Exercise:** Sort the data by the `calories` column.

# %%
# sort by different columns  (calories)

data.sort_values(by = 'calories')
# Out:
#                                   mfr type  calories  protein  fat  sodium  \
# name
# All-Bran with Extra Fiber           K    C        50        4    0     140
# Puffed Rice                         Q    C        50        1    0       0
# Puffed Wheat                        Q    C        50        2    0       0
# 100% Bran                           N    C        70        4    1     130
# All-Bran                            K    C        70        4    1     260
# ...                                ..  ...       ...      ...  ...     ...
# Nutri-Grain Almond-Raisin           K    C       140        3    2     220
# Just Right Fruit & Nut              K    C       140        3    1     170
# Muesli Raisins; Dates; & Almonds    R    C       150        4    3      95
# Muesli Raisins; Peaches; & Pecans   R    C       150        4    3     150
# Mueslix Crispy Blend                K    C       160        3    2     150
#
#                                    fiber  carbo  sugars  potass  ...  weight  \
# name                                                             ...
# All-Bran with Extra Fiber           14.0    8.0       0     330  ...    1.00
# Puffed Rice                          0.0   13.0       0      15  ...    0.50
# Puffed Wheat                         1.0   10.0       0      50  ...    0.50
# 100% Bran                           10.0    5.0       6     280  ...    1.00
# All-Bran                             9.0    7.0       5     320  ...    1.00
# ...                                  ...    ...     ...     ...  ...     ...
# Nutri-Grain Almond-Raisin            3.0   21.0       7     130  ...    1.33
# Just Right Fruit & Nut               2.0   20.0       9      95  ...    1.30
# Muesli Raisins; Dates; & Almonds     3.0   16.0      11     170  ...    1.00
# Muesli Raisins; Peaches; & Pecans    3.0   16.0      11     170  ...    1.00
# Mueslix Crispy Blend                 3.0   17.0      13     160  ...    1.50
#
#                                    cups     rating  myrating  my rating20  \
# name
# All-Bran with Extra Fiber          0.50  93.704912       NaN          NaN
# Puffed Rice                        1.00  60.756112       NaN          NaN
# Puffed Wheat                       1.00  63.005645       NaN          NaN
# 100% Bran                          0.33  68.402973       1.0         20.0
# All-Bran                           0.33  59.425505       NaN          NaN
# ...                                 ...        ...       ...          ...
# Nutri-Grain Almond-Raisin          0.67  40.692320       NaN          NaN
# Just Right Fruit & Nut             0.75  36.471512       NaN          NaN
# Muesli Raisins; Dates; & Almonds   1.00  37.136863       NaN          NaN
# Muesli Raisins; Peaches; & Pecans  1.00  34.139765       NaN          NaN
# Mueslix Crispy Blend               0.67  30.313351       NaN          NaN
#
#                                         diff   calPerCup  proPerCup  \
# name
# All-Bran with Extra Fiber                NaN  100.000000   8.000000
# Puffed Rice                              NaN   50.000000   1.000000
# Puffed Wheat                             NaN   50.000000   2.000000
# 100% Bran                          48.402973  212.121212  12.121212
# All-Bran                                 NaN  212.121212  12.121212
# ...                                      ...         ...        ...
# Nutri-Grain Almond-Raisin                NaN  208.955224   4.477612
# Just Right Fruit & Nut                   NaN  186.666667   4.000000
# Muesli Raisins; Dates; & Almonds         NaN  150.000000   4.000000
# Muesli Raisins; Peaches; & Pecans        NaN  150.000000   4.000000
# Mueslix Crispy Blend                     NaN  238.805970   4.477612
#
#                                    fatPerCup  sugPerCup
# name
# All-Bran with Extra Fiber           0.000000   0.000000
# Puffed Rice                         0.000000   0.000000
# Puffed Wheat                        0.000000   0.000000
# 100% Bran                           3.030303  18.181818
# All-Bran                            3.030303  15.151515
# ...                                      ...        ...
# Nutri-Grain Almond-Raisin           2.985075  10.447761
# Just Right Fruit & Nut              1.333333  12.000000
# Muesli Raisins; Dates; & Almonds    3.000000  11.000000
# Muesli Raisins; Peaches; & Pecans   3.000000  11.000000
# Mueslix Crispy Blend                2.985075  19.402985
#
# [77 rows x 22 columns]

# %% [markdown]
# **Exercise:** Sort the data by `calories` and then `mfr`.

# %%
# sort by multiple columns  (calories, mfr)

data.sort_values(by = ['calories', 'mfr'])
# Out:
#                                   mfr type  calories  protein  fat  sodium  \
# name
# All-Bran with Extra Fiber           K    C        50        4    0     140
# Puffed Rice                         Q    C        50        1    0       0
# Puffed Wheat                        Q    C        50        2    0       0
# All-Bran                            K    C        70        4    1     260
# 100% Bran                           N    C        70        4    1     130
# ...                                ..  ...       ...      ...  ...     ...
# Just Right Fruit & Nut              K    C       140        3    1     170
# Nutri-Grain Almond-Raisin           K    C       140        3    2     220
# Muesli Raisins; Dates; & Almonds    R    C       150        4    3      95
# Muesli Raisins; Peaches; & Pecans   R    C       150        4    3     150
# Mueslix Crispy Blend                K    C       160        3    2     150
#
#                                    fiber  carbo  sugars  potass  ...  weight  \
# name                                                             ...
# All-Bran with Extra Fiber           14.0    8.0       0     330  ...    1.00
# Puffed Rice                          0.0   13.0       0      15  ...    0.50
# Puffed Wheat                         1.0   10.0       0      50  ...    0.50
# All-Bran                             9.0    7.0       5     320  ...    1.00
# 100% Bran                           10.0    5.0       6     280  ...    1.00
# ...                                  ...    ...     ...     ...  ...     ...
# Just Right Fruit & Nut               2.0   20.0       9      95  ...    1.30
# Nutri-Grain Almond-Raisin            3.0   21.0       7     130  ...    1.33
# Muesli Raisins; Dates; & Almonds     3.0   16.0      11     170  ...    1.00
# Muesli Raisins; Peaches; & Pecans    3.0   16.0      11     170  ...    1.00
# Mueslix Crispy Blend                 3.0   17.0      13     160  ...    1.50
#
#                                    cups     rating  myrating  my rating20  \
# name
# All-Bran with Extra Fiber          0.50  93.704912       NaN          NaN
# Puffed Rice                        1.00  60.756112       NaN          NaN
# Puffed Wheat                       1.00  63.005645       NaN          NaN
# All-Bran                           0.33  59.425505       NaN          NaN
# 100% Bran                          0.33  68.402973       1.0         20.0
# ...                                 ...        ...       ...          ...
# Just Right Fruit & Nut             0.75  36.471512       NaN          NaN
# Nutri-Grain Almond-Raisin          0.67  40.692320       NaN          NaN
# Muesli Raisins; Dates; & Almonds   1.00  37.136863       NaN          NaN
# Muesli Raisins; Peaches; & Pecans  1.00  34.139765       NaN          NaN
# Mueslix Crispy Blend               0.67  30.313351       NaN          NaN
#
#                                         diff   calPerCup  proPerCup  \
# name
# All-Bran with Extra Fiber                NaN  100.000000   8.000000
# Puffed Rice                              NaN   50.000000   1.000000
# Puffed Wheat                             NaN   50.000000   2.000000
# All-Bran                                 NaN  212.121212  12.121212
# 100% Bran                          48.402973  212.121212  12.121212
# ...                                      ...         ...        ...
# Just Right Fruit & Nut                   NaN  186.666667   4.000000
# Nutri-Grain Almond-Raisin                NaN  208.955224   4.477612
# Muesli Raisins; Dates; & Almonds         NaN  150.000000   4.000000
# Muesli Raisins; Peaches; & Pecans        NaN  150.000000   4.000000
# Mueslix Crispy Blend                     NaN  238.805970   4.477612
#
#                                    fatPerCup  sugPerCup
# name
# All-Bran with Extra Fiber           0.000000   0.000000
# Puffed Rice                         0.000000   0.000000
# Puffed Wheat                        0.000000   0.000000
# All-Bran                            3.030303  15.151515
# 100% Bran                           3.030303  18.181818
# ...                                      ...        ...
# Just Right Fruit & Nut              1.333333  12.000000
# Nutri-Grain Almond-Raisin           2.985075  10.447761
# Muesli Raisins; Dates; & Almonds    3.000000  11.000000
# Muesli Raisins; Peaches; & Pecans   3.000000  11.000000
# Mueslix Crispy Blend                2.985075  19.402985
#
# [77 rows x 22 columns]

# %% [markdown]
# ## Descriptive stats
#
# Many descriptive stats are available quickly - although you should be careful

# %% [markdown]
# **Exercise:** Sum the entire data by column.

# %%
# sum for all variables

data.sum()
# Out:
# mfr            NQKKRGKGRPQGGGGRKKGKNKGRKKKPKPPGPPPQGPKKGQGARR...
# type           CCCCCCCCCCCCCCCCCCCCHCCCCCCCCCCCCCCCCCCCCCCHCC...
# calories                                                    8230
# protein                                                      196
# fat                                                           78
# sodium                                                     12295
# fiber                                                      165.7
# carbo                                                     1124.0
# sugars                                                       533
# potass                                                      7398
# vitamins                                                    2175
# shelf                                                        170
# weight                                                     79.28
# cups                                                       63.22
# rating                                               3285.259284
# myrating                                                   101.0
# my rating20                                               2020.0
# diff                                                 -756.841486
# calPerCup                                           11047.457146
# proPerCup                                             278.570146
# fatPerCup                                             111.116735
# sugPerCup                                             708.478874
# dtype: object

# %% [markdown]
# **Exercise:** Sum the `calories` column only.

# %%
# sum of calories

data.calories.sum()
# Out:
# 8230

# %% [markdown]
# **Exercise:** Calculate the standard deviation by column.

# %%
# std for all variables

data.std()
# Out:
# C:\Users\coltm\AppData\Local\Temp\ipykernel_19492\3911933190.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# calories       19.484119
# protein         1.094790
# fat             1.006473
# sodium         83.832295
# fiber           2.383364
# carbo           4.278956
# sugars          4.444885
# potass         71.286813
# vitamins       22.342523
# shelf           0.832524
# weight          0.150477
# cups            0.232716
# rating         14.047289
# myrating        1.221035
# my rating20    24.420708
# diff           30.398210
# calPerCup      60.224368
# proPerCup       2.499900
# fatPerCup       1.645827
# sugPerCup       5.985441
# dtype: float64

# %% [markdown]
# **Exercise:** Calculate the standard deviation for the `calories` column.

# %%
# std of calories

data['calories'].std()
# Out:
# 19.48411905682084

# %% [markdown]
# **Exercise:** Sum all variables by observation.  Note that the information here is for illustrative purposes only and the output is not useful.

# %%
# sum by observation
# the output here is non useful - only for illustrative purposes

data.sum(axis = 'columns')   # this summed everything in each row, so calories+protein+sugars+fiber+etc -> hence why not so useful
# Out:
# C:\Users\coltm\AppData\Local\Temp\ipykernel_19492\2040396456.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.sum(axis = 'columns')   # this summed everything in each row, so calories+protein+sugars+fiber+etc -> hence why not so useful
# name
# 100% Bran                     918.590491
# 100% Natural Bran             470.983679
# All-Bran                     1007.179747
# All-Bran with Extra Fiber     777.204912
# Almond Delight                599.186353
#                                 ...
# Triples                       670.522841
# Trix                          511.506602
# Wheat Chex                    709.158938
# Wheaties                      678.184386
# Wheaties Honey Gold           661.458451
# Length: 77, dtype: float64

# %% [markdown]
# Some methods are not direct stats - but use them

# %% [markdown]
# **Exercise:**  What is the index value of the cereal that has the maximum calories?

# %%
# identify index value of maximum for calories

data.calories.idxmax()
# Out:
# 'Mueslix Crispy Blend'

# %% [markdown]
# **Exercise:** What is the index value of the cereal that has the minimum calories?

# %%
# identify index value of minimum for calories

data.calories.idxmin()
# Out:
# 'All-Bran with Extra Fiber'

# %% [markdown]
# Correlation and covariance work well with DataFrames

# %% [markdown]
# **Exercise:** What is the correlation for all numeric variables in the data?

# %%
# correlation for all numeric variables in the df

data.corr()
# Out:
#              calories   protein       fat    sodium     fiber     carbo  \
# calories     1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein      0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat          0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium       0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber       -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo        0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars       0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass      -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins     0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf        0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight       0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups         0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating      -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
# myrating     0.515270  0.122558  0.270226  0.012588  0.046744 -0.135352
# my rating20  0.515270  0.122558  0.270226  0.012588  0.046744 -0.135352
# diff        -0.722729  0.155343 -0.344286 -0.142200  0.192644  0.122348
# calPerCup    0.337821  0.220932  0.334962  0.031868  0.256096 -0.137202
# proPerCup   -0.147650  0.698604  0.167308 -0.081261  0.674040 -0.330238
# fatPerCup    0.351844  0.228848  0.873212 -0.039145  0.145162 -0.366640
# sugPerCup    0.454931 -0.152155  0.330257  0.093967  0.095049 -0.420701
#
#                sugars    potass  vitamins     shelf    weight      cups  \
# calories     0.562340 -0.066609  0.265356  0.097234  0.696091  0.087200
# protein     -0.329142  0.549407  0.007335  0.133865  0.216158 -0.244469
# fat          0.270819  0.193279 -0.031156  0.263691  0.214625 -0.175892
# sodium       0.101451 -0.032603  0.361477 -0.069719  0.308576  0.119665
# fiber       -0.141205  0.903374 -0.032243  0.297539  0.247226 -0.513061
# carbo       -0.331665 -0.349685  0.258148 -0.101790  0.135136  0.363932
# sugars       1.000000  0.021696  0.125137  0.100438  0.450648 -0.032358
# potass       0.021696  1.000000  0.020699  0.360663  0.416303 -0.495195
# vitamins     0.125137  0.020699  1.000000  0.299262  0.320324  0.128405
# shelf        0.100438  0.360663  0.299262  1.000000  0.190762 -0.335269
# weight       0.450648  0.416303  0.320324  0.190762  1.000000 -0.199583
# cups        -0.032358 -0.495195  0.128405 -0.335269 -0.199583  1.000000
# rating      -0.759675  0.380165 -0.240544  0.025159 -0.298124 -0.203160
# myrating     0.303967  0.242193  0.303953  0.199229  0.432062 -0.219874
# my rating20  0.303967  0.242193  0.303953  0.199229  0.432062 -0.219874
# diff        -0.541732 -0.045759 -0.373986 -0.197677 -0.441780  0.133541
# calPerCup    0.161480  0.318346 -0.003091  0.358350  0.379858 -0.788987
# proPerCup   -0.237608  0.652837 -0.074182  0.316951  0.158886 -0.739963
# fatPerCup    0.179369  0.265298 -0.057393  0.317631  0.193720 -0.454542
# sugPerCup    0.865105  0.245860  0.060221  0.275862  0.483678 -0.459931
#
#                rating  myrating  my rating20      diff  calPerCup  proPerCup  \
# calories    -0.689376  0.515270     0.515270 -0.722729   0.337821  -0.147650
# protein      0.470618  0.122558     0.122558  0.155343   0.220932   0.698604
# fat         -0.409284  0.270226     0.270226 -0.344286   0.334962   0.167308
# sodium      -0.401295  0.012588     0.012588 -0.142200   0.031868  -0.081261
# fiber        0.584160  0.046744     0.046744  0.192644   0.256096   0.674040
# carbo        0.052055 -0.135352    -0.135352  0.122348  -0.137202  -0.330238
# sugars      -0.759675  0.303967     0.303967 -0.541732   0.161480  -0.237608
# potass       0.380165  0.242193     0.242193 -0.045759   0.318346   0.652837
# vitamins    -0.240544  0.303953     0.303953 -0.373986  -0.003091  -0.074182
# shelf        0.025159  0.199229     0.199229 -0.197677   0.358350   0.316951
# weight      -0.298124  0.432062     0.432062 -0.441780   0.379858   0.158886
# cups        -0.203160 -0.219874    -0.219874  0.133541  -0.788987  -0.739963
# rating       1.000000 -0.276081    -0.276081  0.635456  -0.086698   0.461810
# myrating    -0.276081  1.000000     1.000000 -0.917565   0.305016   0.006381
# my rating20 -0.276081  1.000000     1.000000 -0.917565   0.305016   0.006381
# diff         0.635456 -0.917565    -0.917565  1.000000  -0.261627   0.250285
# calPerCup   -0.086698  0.305016     0.305016 -0.261627   1.000000   0.695173
# proPerCup    0.461810  0.006381     0.006381  0.250285   0.695173   1.000000
# fatPerCup   -0.262839  0.265319     0.265319 -0.268569   0.571156   0.408003
# sugPerCup   -0.580153  0.282406     0.282406 -0.430485   0.536480   0.171637
#
#              fatPerCup  sugPerCup
# calories      0.351844   0.454931
# protein       0.228848  -0.152155
# fat           0.873212   0.330257
# sodium       -0.039145   0.093967
# fiber         0.145162   0.095049
# carbo        -0.366640  -0.420701
# sugars        0.179369   0.865105
# potass        0.265298   0.245860
# vitamins     -0.057393   0.060221
# shelf         0.317631   0.275862
# weight        0.193720   0.483678
# cups         -0.454542  -0.459931
# rating       -0.262839  -0.580153
# myrating      0.265319   0.282406
# my rating20   0.265319   0.282406
# diff         -0.268569  -0.430485
# calPerCup     0.571156   0.536480
# proPerCup     0.408003   0.171637
# fatPerCup     1.000000   0.402928
# sugPerCup     0.402928   1.000000

# %% [markdown]
# **Exercise:** What is the covariance for all numeric variables in the data?

# %%
# covariance for all numeric variables in the df

data.cov()
# Out:
#                calories    protein        fat       sodium       fiber  \
# calories     379.630895   0.406699   9.777854   491.079973  -13.625427
# protein        0.406699   1.198565   0.229665    -5.017943    1.305502
# fat            9.777854   0.229665   1.012987    -0.456254    0.040106
# sodium       491.079973  -5.017943  -0.456254  7027.853725  -14.121070
# fiber        -13.625427   1.305502   0.040106   -14.121070    5.680424
# carbo         20.899692  -0.613038  -1.369703   127.696514   -3.631442
# sugars        48.701299  -1.601675   1.211552    37.803315   -1.495899
# potass       -92.517088  42.877990  13.867396  -194.842789  153.485373
# vitamins     115.516063   0.179426  -0.700615   677.054853   -1.716934
# shelf          1.577239   0.122010   0.220950    -4.865858    0.590379
# weight         2.040875   0.035610   0.032505     3.892635    0.088665
# cups           0.395386  -0.062285  -0.041198     2.334552   -0.284568
# rating      -188.681562   7.237560  -5.786539  -472.571837   19.557575
# myrating       7.399194   0.204637   0.290323     1.199597    0.123488
# my rating20  147.983871   4.092742   5.806452    23.991935    2.469758
# diff        -258.371533   6.457373  -9.208579  -337.359011   12.669954
# calPerCup    396.405602  14.566694  20.303437   160.891632   36.759167
# proPerCup     -7.191800   1.911985   0.420961   -17.030002    4.016044
# fatPerCup     11.282749   0.412347   1.446458    -5.400992    0.569414
# sugPerCup     53.054578  -0.997044   1.989531    47.150042    1.355922
#
#                   carbo     sugars       potass    vitamins      shelf  \
# calories      20.899692  48.701299   -92.517088  115.516063   1.577239
# protein       -0.613038  -1.601675    42.877990    0.179426   0.122010
# fat           -1.369703   1.211552    13.867396   -0.700615   0.220950
# sodium       127.696514  37.803315  -194.842789  677.054853  -4.865858
# fiber         -3.631442  -1.495899   153.485373   -1.716934   0.590379
# carbo         18.309467  -6.308100  -106.665584   24.679597  -0.362611
# sugars        -6.308100  19.757006     6.874573   12.427375   0.371668
# potass      -106.665584   6.874573  5081.809638   32.967362  21.404648
# vitamins      24.679597  12.427375    32.967362  499.188312   5.566473
# shelf         -0.362611   0.371668    21.404648    5.566473   0.693096
# weight         0.087012   0.301417     4.465689    1.076940   0.023898
# cups           0.362397  -0.033471    -8.215082    0.667635  -0.064956
# rating         3.128888 -47.433013   380.692445  -75.495061   0.294225
# myrating      -0.781250   1.717742    22.013105    5.519153   0.186492
# my rating20  -15.625000  34.354839   440.262097  110.383065   3.729839
# diff          17.581024 -76.214235  -103.541527 -169.060182  -4.606632
# calPerCup    -35.356697  43.226566  1366.725837   -4.159586  17.967042
# proPerCup     -3.532545  -2.640248   116.342017   -4.143372   0.659648
# fatPerCup     -2.582036   1.312178    31.126259   -2.110467   0.435214
# sugPerCup    -10.774766  23.015773   104.904154    8.053386   1.374628
#
#                weight       cups      rating   myrating  my rating20  \
# calories     2.040875   0.395386 -188.681562   7.399194   147.983871
# protein      0.035610  -0.062285    7.237560   0.204637     4.092742
# fat          0.032505  -0.041198   -5.786539   0.290323     5.806452
# sodium       3.892635   2.334552 -472.571837   1.199597    23.991935
# fiber        0.088665  -0.284568   19.557575   0.123488     2.469758
# carbo        0.087012   0.362397    3.128888  -0.781250   -15.625000
# sugars       0.301417  -0.033471  -47.433013   1.717742    34.354839
# potass       4.465689  -8.215082  380.692445  22.013105   440.262097
# vitamins     1.076940   0.667635  -75.495061   5.519153   110.383065
# shelf        0.023898  -0.064956    0.294225   0.186492     3.729839
# weight       0.022643  -0.006989   -0.630172   0.064687     1.293750
# cups        -0.006989   0.054157   -0.664137  -0.060927    -1.218548
# rating      -0.630172  -0.664137  197.326321  -4.238967   -84.779350
# myrating     0.064687  -0.060927   -4.238967   1.490927    29.818548
# my rating20  1.293750  -1.218548  -84.779350  29.818548   596.370968
# diff        -1.646645   0.921239  242.900850 -34.057516  -681.150317
# calPerCup    3.442418 -11.057799  -73.345912  13.418722   268.374449
# proPerCup    0.059769  -0.430486   16.217315   0.019485     0.389701
# fatPerCup    0.047976  -0.174094   -6.076672   0.457876     9.157512
# sugPerCup    0.435635  -0.640642  -48.778786   2.068687    41.373738
#
#                    diff    calPerCup   proPerCup  fatPerCup   sugPerCup
# calories    -258.371533   396.405602   -7.191800  11.282749   53.054578
# protein        6.457373    14.566694    1.911985   0.412347   -0.997044
# fat           -9.208579    20.303437    0.420961   1.446458    1.989531
# sodium      -337.359011   160.891632  -17.030002  -5.400992   47.150042
# fiber         12.669954    36.759167    4.016044   0.569414    1.355922
# carbo         17.581024   -35.356697   -3.532545  -2.582036  -10.774766
# sugars       -76.214235    43.226566   -2.640248   1.312178   23.015773
# potass      -103.541527  1366.725837  116.342017  31.126259  104.904154
# vitamins    -169.060182    -4.159586   -4.143372  -2.110467    8.053386
# shelf         -4.606632    17.967042    0.659648   0.435214    1.374628
# weight        -1.646645     3.442418    0.059769   0.047976    0.435635
# cups           0.921239   -11.057799   -0.430486  -0.174094   -0.640642
# rating       242.900850   -73.345912   16.217315  -6.076672  -48.778786
# myrating     -34.057516    13.418722    0.019485   0.457876    2.068687
# my rating20 -681.150317   268.374449    0.389701   9.157512   41.373738
# diff         924.051168  -286.544543   19.025918 -11.538629  -78.505239
# calPerCup   -286.544543  3626.974507  104.661759  56.612307  193.384468
# proPerCup     19.025918   104.661759    6.249502   1.678687    2.568210
# fatPerCup    -11.538629    56.612307    1.678687   2.708745    3.969247
# sugPerCup    -78.505239   193.384468    2.568210   3.969247   35.825502
